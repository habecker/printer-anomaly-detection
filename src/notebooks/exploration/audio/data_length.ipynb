# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
from printer_anomaly_detection.dataset.audio import get_audio_dataset_files_by_phase, Split, get_audio_duration, get_audio_dataset_files, Outcome
import numpy as np

project_path = Path('../../../../')
dataset_path = project_path / 'datasets' / 'prints'

# %%
list(get_audio_dataset_files_by_phase(dataset_path, 'original', Split.TRAIN))
# Out:
# [PosixPath('../../../../datasets/prints/test/audio.mp4'),
#  PosixPath('../../../../datasets/prints/cable_clips/audio.mp4'),
#  PosixPath('../../../../datasets/prints/cable_clips2/audio.mp4')]

# %%
np.sum([get_audio_duration(p) for p in get_audio_dataset_files_by_phase(dataset_path, 'original', Split.TRAIN)])
# Out:
# /home/y2g/projects/personal/printer-anomaly-detection/src/printer_anomaly_detection/dataset/audio.py:31: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   return librosa.get_duration(filename=path.as_posix())
# /home/y2g/projects/personal/printer-anomaly-detection/src/printer_anomaly_detection/dataset/audio.py:31: FutureWarning: PySoundFile failed. Trying audioread instead.
# 	Audioread support is deprecated in librosa 0.10.0 and will be removed in version 1.0.
#   return librosa.get_duration(filename=path.as_posix())
# /home/y2g/projects/personal/printer-anomaly-detection/src/printer_anomaly_detection/dataset/audio.py:31: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   return librosa.get_duration(filename=path.as_posix())
# ...

# %%
from printer_anomaly_detection.dataset.domain import Datetime


duration = np.sum([get_audio_duration(p) for p in get_audio_dataset_files(dataset_path, Datetime.min, Datetime.max, outcomes={Outcome.SUCCESS, Outcome.FAILURE})])
# Out:
# /home/y2g/projects/personal/printer-anomaly-detection/src/printer_anomaly_detection/dataset/audio.py:31: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   return librosa.get_duration(filename=path.as_posix())
# /home/y2g/projects/personal/printer-anomaly-detection/src/printer_anomaly_detection/dataset/audio.py:31: FutureWarning: PySoundFile failed. Trying audioread instead.
# 	Audioread support is deprecated in librosa 0.10.0 and will be removed in version 1.0.
#   return librosa.get_duration(filename=path.as_posix())
# /home/y2g/projects/personal/printer-anomaly-detection/src/printer_anomaly_detection/dataset/audio.py:31: FutureWarning: get_duration() keyword argument 'filename' has been renamed to 'path' in version 0.10.0.
# 	This alias will be removed in version 1.0.
#   return librosa.get_duration(filename=path.as_posix())
# ...

# %%
# in HH'h' MM'm' format
print(f'{duration // 3600}h {(duration % 3600) // 60}m')
# Out:
# 38.0h 55.0m
