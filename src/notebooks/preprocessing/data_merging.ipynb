# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
import pandas as pd

# %%
DATASET = 'hinges_12'

# %%
DATASETS_PATH = Path.cwd().parent.parent / 'datasets' / 'prints'
dataset_path = DATASETS_PATH / DATASET

# %%
extruder_power_path = dataset_path / 'extruder_power.csv.gz'
extruder_target_path = dataset_path / 'extruder_target.csv.gz'
extruder_temperature = dataset_path / 'extruder_temperature.csv.gz'
extruder_velocity = dataset_path / 'extruder_velocity_sensor.csv.gz'
gas = dataset_path / 'gas.csv.gz'
heater_power = dataset_path / 'heater_power.csv.gz'
heater_target = dataset_path / 'heater_target.csv.gz'
heater_temperature = dataset_path / 'heater_temperature.csv.gz'
imu = dataset_path / 'imu.csv.gz'
mcu = dataset_path / 'mcu.csv.gz'
position = dataset_path / 'position_sensor.csv.gz'
position_target = dataset_path / 'position_target.csv.gz'
velocity = dataset_path / 'velocity_sensor.csv.gz'
velocity_target = dataset_path / 'velocity_target.csv.gz'

# %%
from typing import Dict

from printer_anomaly_detection.dataset.domain import Sensor


sensor_filenames: Dict[Sensor, str] = {
    Sensor.EXTRUDER_POWER: 'extruder_power.csv.gz',
    Sensor.EXTRUDER_TARGET: 'extruder_target.csv.gz',
    Sensor.EXTRUDER_TEMPERATURE: 'extruder_temperature.csv.gz',
    Sensor.EXTRUDER_VELOCITY: 'extruder_velocity_sensor.csv.gz',
    Sensor.GAS: 'gas.csv.gz',
    Sensor.HEATER_POWER: 'heater_power.csv.gz',
    Sensor.HEATER_TARGET: 'heater_target.csv.gz',
    Sensor.HEATER_TEMPERATURE: 'heater_temperature.csv.gz',
    Sensor.ACCELEROMETER: 'accelerometer.csv.gz',
    Sensor.MAGNETOMETER: 'magnetometer.csv.gz',
    Sensor.GYROSCOPE: 'gyroscope.csv.gz',
    Sensor.MCU: 'mcu.csv.gz',
    Sensor.POSITION: 'position_sensor.csv.gz',
    Sensor.POSITION_TARGET: 'position_target.csv.gz',
    Sensor.VELOCITY: 'velocity_sensor.csv.gz',
    Sensor.VELOCITY_TARGET: 'velocity_target.csv.gz',
}

# %%
from typing import Type
from printer_anomaly_detection.dataset.domain.printer import *

from printer_anomaly_detection.dataset.domain.sensors import *

sensor_datatypes: Dict[Sensor, Type[SensorData]] = {
    Sensor.EXTRUDER_POWER: PowerSensorData,
    Sensor.EXTRUDER_TARGET: TargetData,
    Sensor.EXTRUDER_TEMPERATURE: TemperatureSensorData,
    Sensor.EXTRUDER_VELOCITY: VelocitySensorData,
    Sensor.GAS: GasSensorData,
    Sensor.HEATER_POWER: PowerSensorData,
    Sensor.HEATER_TARGET: TargetData,
    Sensor.HEATER_TEMPERATURE: TemperatureSensorData,
    Sensor.ACCELEROMETER: IMUSensorData,
    Sensor.MAGNETOMETER: IMUSensorData,
    Sensor.GYROSCOPE: IMUSensorData,
    Sensor.MCU: MCUData,
    Sensor.POSITION: PositionSensorData,
    Sensor.POSITION_TARGET: PositionTargetData,
    Sensor.VELOCITY: VelocitySensorData,
    Sensor.VELOCITY_TARGET: VelocityTargetData,
}

# %%
pd.read_csv(extruder_power_path)
# Out:
#                        datetime sensor_type     power
# 0    2023-06-01T12:44:59.136277           E  1.000000
# 1    2023-06-01T12:46:14.643423           E  0.930071
# 2    2023-06-01T12:46:15.144622           E  0.869064
# 3    2023-06-01T12:46:15.646563           E  0.765104
# 4    2023-06-01T12:46:16.650460           E  0.674389
# ..                          ...         ...       ...
# 506  2023-06-01T13:13:29.127487           E  0.486161
# 507  2023-06-01T13:13:30.381189           E  0.404879
# 508  2023-06-01T13:13:33.639039           E  0.341342
# 509  2023-06-01T13:13:37.900606           E  0.311557
# 510  2023-06-01T13:13:40.909543           E  0.000000
#
# [511 rows x 3 columns]

# %%
from typing import Type
from dataclass_csv import DataclassReader
import gzip

from printer_anomaly_detection.dataset.domain.printer import PowerSensorData

def read_csv(path: Path, dataclass_type: Type):
    with gzip.open(path, 'rt', encoding='utf-8') as f:
        return list(DataclassReader(f, dataclass_type))

# %%
pd.DataFrame(read_csv(extruder_power_path, PowerSensorData))
# Out:
#                        datetime sensor_type     power
# 0    2023-06-01T12:44:59.136277           E  1.000000
# 1    2023-06-01T12:46:14.643423           E  0.930071
# 2    2023-06-01T12:46:15.144622           E  0.869064
# 3    2023-06-01T12:46:15.646563           E  0.765104
# 4    2023-06-01T12:46:16.650460           E  0.674389
# ..                          ...         ...       ...
# 506  2023-06-01T13:13:29.127487           E  0.486161
# 507  2023-06-01T13:13:30.381189           E  0.404879
# 508  2023-06-01T13:13:33.639039           E  0.341342
# 509  2023-06-01T13:13:37.900606           E  0.311557
# 510  2023-06-01T13:13:40.909543           E  0.000000
#
# [511 rows x 3 columns]

# %%
read_csv(extruder_power_path, PowerSensorData)
# Out:
# [PowerSensorData(datetime=2023-06-01T12:44:59.136277, sensor_type=<SensorType.EXTRUDER: 'E'>, power=1.0),
#  PowerSensorData(datetime=2023-06-01T12:46:14.643423, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.9300709308913256),
#  PowerSensorData(datetime=2023-06-01T12:46:15.144622, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.8690644675100611),
#  PowerSensorData(datetime=2023-06-01T12:46:15.646563, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.7651043138269606),
#  PowerSensorData(datetime=2023-06-01T12:46:16.650460, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.6743891049443522),
#  PowerSensorData(datetime=2023-06-01T12:46:17.151408, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.6114876047237948),
#  PowerSensorData(datetime=2023-06-01T12:46:17.904145, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.5222718698023764),
#  PowerSensorData(datetime=2023-06-01T12:46:18.656823, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45628944884787515),
#  PowerSensorData(datetime=2023-06-01T12:46:19.661035, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38704309540721904),
#  PowerSensorData(datetime=2023-06-01T12:46:20.914123, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.33482057760475437),
#  PowerSensorData(datetime=2023-06-01T12:46:24.926377, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3574164904081042),
#  PowerSensorData(datetime=2023-06-01T12:46:27.435134, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41437140383445037),
#  PowerSensorData(datetime=2023-06-01T12:46:31.700577, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39638973993412213),
#  PowerSensorData(datetime=2023-06-01T12:46:34.711351, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3452639443866142),
#  PowerSensorData(datetime=2023-06-01T12:46:38.727722, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.28648299028160573),
#  PowerSensorData(datetime=2023-06-01T12:46:42.991519, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.32358183968093884),
#  PowerSensorData(datetime=2023-06-01T12:46:47.254427, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.330913333242939),
#  PowerSensorData(datetime=2023-06-01T12:46:49.259976, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38317799533693453),
#  PowerSensorData(datetime=2023-06-01T12:46:53.523041, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3472414959130412),
#  PowerSensorData(datetime=2023-06-01T12:46:57.784802, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.35562469688867776),
#  PowerSensorData(datetime=2023-06-01T12:47:02.047608, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.35841946412943226),
#  PowerSensorData(datetime=2023-06-01T12:47:03.050724, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4443525698128586),
#  PowerSensorData(datetime=2023-06-01T12:47:03.552620, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3689313325493401),
#  PowerSensorData(datetime=2023-06-01T12:47:04.555903, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43683136103470505),
#  PowerSensorData(datetime=2023-06-01T12:47:07.314018, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.5059928755105618),
#  PowerSensorData(datetime=2023-06-01T12:47:11.579938, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.48051191145042355),
#  PowerSensorData(datetime=2023-06-01T12:47:11.831055, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.5440559629757656),
#  PowerSensorData(datetime=2023-06-01T12:47:12.081964, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4884723271777428),
#  PowerSensorData(datetime=2023-06-01T12:47:16.345925, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.46534117725237323),
#  PowerSensorData(datetime=2023-06-01T12:47:18.853387, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40316304283239923),
#  PowerSensorData(datetime=2023-06-01T12:47:22.864018, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4201051846761906),
#  PowerSensorData(datetime=2023-06-01T12:47:27.127971, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42845539252801457),
#  PowerSensorData(datetime=2023-06-01T12:47:31.390439, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42818122659514746),
#  PowerSensorData(datetime=2023-06-01T12:47:35.652260, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44033741056443926),
#  PowerSensorData(datetime=2023-06-01T12:47:39.663274, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4207360955424541),
#  PowerSensorData(datetime=2023-06-01T12:47:43.929213, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42172593077285864),
#  PowerSensorData(datetime=2023-06-01T12:47:48.203443, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43276421445588187),
#  PowerSensorData(datetime=2023-06-01T12:47:52.213415, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44478743218121675),
#  PowerSensorData(datetime=2023-06-01T12:47:56.474443, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44856714174824525),
#  PowerSensorData(datetime=2023-06-01T12:48:00.735428, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4394975348862726),
#  PowerSensorData(datetime=2023-06-01T12:48:03.993603, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38334978534210673),
#  PowerSensorData(datetime=2023-06-01T12:48:08.253375, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4078289798763262),
#  PowerSensorData(datetime=2023-06-01T12:48:12.513674, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4512713939817944),
#  PowerSensorData(datetime=2023-06-01T12:48:16.522982, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4688397087213248),
#  PowerSensorData(datetime=2023-06-01T12:48:20.786258, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44482345383517796),
#  PowerSensorData(datetime=2023-06-01T12:48:25.047761, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38890399570522366),
#  PowerSensorData(datetime=2023-06-01T12:48:29.309446, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4258269839974942),
#  PowerSensorData(datetime=2023-06-01T12:48:33.320523, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.46588027719759234),
#  PowerSensorData(datetime=2023-06-01T12:48:37.585499, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42844842179403025),
#  PowerSensorData(datetime=2023-06-01T12:48:40.091147, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3746886950012222),
#  PowerSensorData(datetime=2023-06-01T12:48:40.341263, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42596476232690655),
#  PowerSensorData(datetime=2023-06-01T12:48:42.345969, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.36676336213762084),
#  PowerSensorData(datetime=2023-06-01T12:48:45.605633, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44449941132814486),
#  PowerSensorData(datetime=2023-06-01T12:48:49.865126, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4538075552936742),
#  PowerSensorData(datetime=2023-06-01T12:48:54.127231, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43734974870197096),
#  PowerSensorData(datetime=2023-06-01T12:48:58.390910, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3981830696828514),
#  PowerSensorData(datetime=2023-06-01T12:49:01.898396, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45086981218044875),
#  PowerSensorData(datetime=2023-06-01T12:49:06.163878, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45820261418107877),
#  PowerSensorData(datetime=2023-06-01T12:49:10.426413, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41819074972082315),
#  PowerSensorData(datetime=2023-06-01T12:49:14.186125, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.35231965110461333),
#  PowerSensorData(datetime=2023-06-01T12:49:14.437233, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40899404534140615),
#  PowerSensorData(datetime=2023-06-01T12:49:18.699444, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4407623282526233),
#  PowerSensorData(datetime=2023-06-01T12:49:20.712469, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.32706649517703323),
#  PowerSensorData(datetime=2023-06-01T12:49:21.213454, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4069034101698576),
#  PowerSensorData(datetime=2023-06-01T12:49:24.973484, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.47523181435818196),
#  PowerSensorData(datetime=2023-06-01T12:49:25.727535, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40461929004289865),
#  PowerSensorData(datetime=2023-06-01T12:49:25.977890, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.457915052863647),
#  PowerSensorData(datetime=2023-06-01T12:49:30.239678, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43059288629781683),
#  PowerSensorData(datetime=2023-06-01T12:49:34.249315, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4243262684410265),
#  PowerSensorData(datetime=2023-06-01T12:49:38.511411, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4154555976422355),
#  PowerSensorData(datetime=2023-06-01T12:49:42.772664, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44031778968167173),
#  PowerSensorData(datetime=2023-06-01T12:49:47.033452, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4430652765378262),
#  PowerSensorData(datetime=2023-06-01T12:49:51.046464, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4349069470332976),
#  PowerSensorData(datetime=2023-06-01T12:49:55.310965, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41241661212335107),
#  PowerSensorData(datetime=2023-06-01T12:49:59.573709, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4744555929137538),
#  PowerSensorData(datetime=2023-06-01T12:50:00.827377, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3853683864850468),
#  PowerSensorData(datetime=2023-06-01T12:50:01.078326, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4666734724465201),
#  PowerSensorData(datetime=2023-06-01T12:50:05.341264, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4614437296357336),
#  PowerSensorData(datetime=2023-06-01T12:50:06.846870, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4081907881875464),
#  PowerSensorData(datetime=2023-06-01T12:50:10.861972, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4100260844647566),
#  PowerSensorData(datetime=2023-06-01T12:50:15.125153, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4548921962520676),
#  PowerSensorData(datetime=2023-06-01T12:50:19.384976, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4554832618214356),
#  PowerSensorData(datetime=2023-06-01T12:50:23.396630, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4092624694144722),
#  PowerSensorData(datetime=2023-06-01T12:50:27.658931, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4203236362354815),
#  PowerSensorData(datetime=2023-06-01T12:50:31.921997, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4831476734262545),
#  PowerSensorData(datetime=2023-06-01T12:50:36.185403, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4550217981908412),
#  PowerSensorData(datetime=2023-06-01T12:50:40.197805, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39633022184615296),
#  PowerSensorData(datetime=2023-06-01T12:50:44.457567, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43956049191721147),
#  PowerSensorData(datetime=2023-06-01T12:50:48.217686, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.36167058741115937),
#  PowerSensorData(datetime=2023-06-01T12:50:48.969732, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4125084883861446),
#  PowerSensorData(datetime=2023-06-01T12:50:53.232134, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4254613439541796),
#  PowerSensorData(datetime=2023-06-01T12:50:57.494318, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.46258441829134544),
#  PowerSensorData(datetime=2023-06-01T12:50:59.251513, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.5133934602719127),
#  PowerSensorData(datetime=2023-06-01T12:50:59.502573, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43907305707112515),
#  PowerSensorData(datetime=2023-06-01T12:51:03.766746, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4388719389238071),
#  PowerSensorData(datetime=2023-06-01T12:51:08.028410, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4333393388826733),
#  PowerSensorData(datetime=2023-06-01T12:51:12.040000, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.46971392887144336),
#  PowerSensorData(datetime=2023-06-01T12:51:16.302826, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4167606947189684),
#  PowerSensorData(datetime=2023-06-01T12:51:20.564921, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42470885351431364),
#  PowerSensorData(datetime=2023-06-01T12:51:24.831993, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42417797754530073),
#  PowerSensorData(datetime=2023-06-01T12:51:27.592216, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.47763968379579524),
#  PowerSensorData(datetime=2023-06-01T12:51:31.352713, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4243586390075669),
#  PowerSensorData(datetime=2023-06-01T12:51:35.614898, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43252599937880604),
#  PowerSensorData(datetime=2023-06-01T12:51:39.627737, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4397829937953707),
#  PowerSensorData(datetime=2023-06-01T12:51:41.633801, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.5135304489165367),
#  PowerSensorData(datetime=2023-06-01T12:51:41.884950, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4554666305752871),
#  PowerSensorData(datetime=2023-06-01T12:51:45.896034, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44642563893394854),
#  PowerSensorData(datetime=2023-06-01T12:51:50.157454, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45691582787159696),
#  PowerSensorData(datetime=2023-06-01T12:51:52.414673, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4031382757857382),
#  PowerSensorData(datetime=2023-06-01T12:51:56.442256, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4026401621639701),
#  PowerSensorData(datetime=2023-06-01T12:52:00.483554, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.46118173375547705),
#  PowerSensorData(datetime=2023-06-01T12:52:04.491803, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.47407915244479315),
#  PowerSensorData(datetime=2023-06-01T12:52:04.993152, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3966879876451896),
#  PowerSensorData(datetime=2023-06-01T12:52:05.244227, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4637043818905515),
#  PowerSensorData(datetime=2023-06-01T12:52:06.756260, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41092285949822016),
#  PowerSensorData(datetime=2023-06-01T12:52:11.018153, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43161294085636814),
#  PowerSensorData(datetime=2023-06-01T12:52:15.029363, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4265337295743619),
#  PowerSensorData(datetime=2023-06-01T12:52:19.292234, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44983651461766594),
#  PowerSensorData(datetime=2023-06-01T12:52:21.046456, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3485073962200971),
#  PowerSensorData(datetime=2023-06-01T12:52:21.296748, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45409742703760464),
#  PowerSensorData(datetime=2023-06-01T12:52:23.804621, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40006472617575417),
#  PowerSensorData(datetime=2023-06-01T12:52:28.066305, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4199583737064613),
#  PowerSensorData(datetime=2023-06-01T12:52:32.326887, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42064051971724703),
#  PowerSensorData(datetime=2023-06-01T12:52:36.339284, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4550432884675617),
#  PowerSensorData(datetime=2023-06-01T12:52:39.346070, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39881808067198643),
#  PowerSensorData(datetime=2023-06-01T12:52:42.605406, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45532272528365486),
#  PowerSensorData(datetime=2023-06-01T12:52:46.867827, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45802116414795946),
#  PowerSensorData(datetime=2023-06-01T12:52:50.127665, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4035183813977777),
#  PowerSensorData(datetime=2023-06-01T12:52:54.387990, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39586423278310034),
#  PowerSensorData(datetime=2023-06-01T12:52:57.644538, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4616870392342106),
#  PowerSensorData(datetime=2023-06-01T12:53:01.908093, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4323362636704611),
#  PowerSensorData(datetime=2023-06-01T12:53:06.168985, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39391501185612754),
#  PowerSensorData(datetime=2023-06-01T12:53:10.431244, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38658776892633273),
#  PowerSensorData(datetime=2023-06-01T12:53:13.689957, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4416728261681099),
#  PowerSensorData(datetime=2023-06-01T12:53:17.703710, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4636765422863498),
#  PowerSensorData(datetime=2023-06-01T12:53:21.966246, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4662523999458321),
#  PowerSensorData(datetime=2023-06-01T12:53:23.220106, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4139571032800284),
#  PowerSensorData(datetime=2023-06-01T12:53:27.479823, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4097715449977102),
#  PowerSensorData(datetime=2023-06-01T12:53:31.497266, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4389233808593353),
#  PowerSensorData(datetime=2023-06-01T12:53:35.770627, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42512366787396866),
#  PowerSensorData(datetime=2023-06-01T12:53:40.034639, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42990846388138054),
#  PowerSensorData(datetime=2023-06-01T12:53:44.298146, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41595121159924947),
#  PowerSensorData(datetime=2023-06-01T12:53:46.302993, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4748968252407723),
#  PowerSensorData(datetime=2023-06-01T12:53:50.570892, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4125328936040262),
#  PowerSensorData(datetime=2023-06-01T12:53:54.583988, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.36775456300659964),
#  PowerSensorData(datetime=2023-06-01T12:53:58.593925, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43116206436534465),
#  PowerSensorData(datetime=2023-06-01T12:54:02.870681, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4628192644948515),
#  PowerSensorData(datetime=2023-06-01T12:54:06.884308, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4555881306393457),
#  PowerSensorData(datetime=2023-06-01T12:54:10.645325, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3969114929788644),
#  PowerSensorData(datetime=2023-06-01T12:54:14.156562, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.346092004297199),
#  PowerSensorData(datetime=2023-06-01T12:54:14.909472, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4037055479137898),
#  PowerSensorData(datetime=2023-06-01T12:54:18.919066, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40796777551747854),
#  PowerSensorData(datetime=2023-06-01T12:54:20.925348, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4596738916515311),
#  PowerSensorData(datetime=2023-06-01T12:54:24.936819, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4752394171227424),
#  PowerSensorData(datetime=2023-06-01T12:54:27.693561, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4216187173731418),
#  PowerSensorData(datetime=2023-06-01T12:54:30.953027, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3699830114900187),
#  PowerSensorData(datetime=2023-06-01T12:54:35.216135, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.409765159820678),
#  PowerSensorData(datetime=2023-06-01T12:54:39.496983, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4863963068305645),
#  PowerSensorData(datetime=2023-06-01T12:54:41.256528, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4291791075057539),
#  PowerSensorData(datetime=2023-06-01T12:54:45.521872, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43801368980922534),
#  PowerSensorData(datetime=2023-06-01T12:54:46.273983, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.49336697744718006),
#  PowerSensorData(datetime=2023-06-01T12:54:47.527409, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4355341499996479),
#  PowerSensorData(datetime=2023-06-01T12:54:51.791875, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4423554920599841),
#  PowerSensorData(datetime=2023-06-01T12:54:55.803392, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41405740081831177),
#  PowerSensorData(datetime=2023-06-01T12:54:56.305064, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3611588763817673),
#  PowerSensorData(datetime=2023-06-01T12:54:56.555889, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4171552020848251),
#  PowerSensorData(datetime=2023-06-01T12:55:00.817497, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41745263372478114),
#  PowerSensorData(datetime=2023-06-01T12:55:04.828848, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38780169851836543),
#  PowerSensorData(datetime=2023-06-01T12:55:05.079515, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44976772039226215),
#  PowerSensorData(datetime=2023-06-01T12:55:06.333025, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39362735650055986),
#  PowerSensorData(datetime=2023-06-01T12:55:08.087720, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4464353637576555),
#  PowerSensorData(datetime=2023-06-01T12:55:12.348904, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4435549944861449),
#  PowerSensorData(datetime=2023-06-01T12:55:15.108348, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38750037492359857),
#  PowerSensorData(datetime=2023-06-01T12:55:19.370243, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38847156493091967),
#  PowerSensorData(datetime=2023-06-01T12:55:22.384148, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4423691381877466),
#  PowerSensorData(datetime=2023-06-01T12:55:26.394244, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.46968915970139696),
#  PowerSensorData(datetime=2023-06-01T12:55:30.654444, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4592745211157942),
#  PowerSensorData(datetime=2023-06-01T12:55:34.418078, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3982736642253685),
#  PowerSensorData(datetime=2023-06-01T12:55:38.428792, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4070493906909471),
#  PowerSensorData(datetime=2023-06-01T12:55:42.690408, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3926091022892329),
#  PowerSensorData(datetime=2023-06-01T12:55:43.191636, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4446101543116972),
#  PowerSensorData(datetime=2023-06-01T12:55:47.452795, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43808204097952186),
#  PowerSensorData(datetime=2023-06-01T12:55:51.720402, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4148466158886134),
#  PowerSensorData(datetime=2023-06-01T12:55:55.981856, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41673070444310045),
#  PowerSensorData(datetime=2023-06-01T12:55:59.993392, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4073695564186083),
#  PowerSensorData(datetime=2023-06-01T12:56:04.256971, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4397521615126289),
#  PowerSensorData(datetime=2023-06-01T12:56:08.519820, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4747107392396024),
#  PowerSensorData(datetime=2023-06-01T12:56:12.788223, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4489664627082243),
#  PowerSensorData(datetime=2023-06-01T12:56:14.292552, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3880482663870645),
#  PowerSensorData(datetime=2023-06-01T12:56:18.303594, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.36713007708203704),
#  PowerSensorData(datetime=2023-06-01T12:56:21.061977, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41975529400053213),
#  PowerSensorData(datetime=2023-06-01T12:56:25.331419, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44534090243048347),
#  PowerSensorData(datetime=2023-06-01T12:56:29.104237, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.5090443044463286),
#  PowerSensorData(datetime=2023-06-01T12:56:29.856253, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4566836733004112),
#  PowerSensorData(datetime=2023-06-01T12:56:34.116101, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4423105050514834),
#  PowerSensorData(datetime=2023-06-01T12:56:37.374654, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38202448769673303),
#  PowerSensorData(datetime=2023-06-01T12:56:41.386799, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38183304178376476),
#  PowerSensorData(datetime=2023-06-01T12:56:43.392190, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4391532299173186),
#  PowerSensorData(datetime=2023-06-01T12:56:47.405118, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.46909037312704044),
#  PowerSensorData(datetime=2023-06-01T12:56:50.163152, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.416992867025958),
#  PowerSensorData(datetime=2023-06-01T12:56:50.915351, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4812005948149936),
#  PowerSensorData(datetime=2023-06-01T12:56:51.165844, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4225791809888258),
#  PowerSensorData(datetime=2023-06-01T12:56:55.178463, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42265373729656786),
#  PowerSensorData(datetime=2023-06-01T12:56:59.438983, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39343216400569886),
#  PowerSensorData(datetime=2023-06-01T12:57:02.696990, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4548338221369457),
#  PowerSensorData(datetime=2023-06-01T12:57:06.959270, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4440977712179529),
#  PowerSensorData(datetime=2023-06-01T12:57:09.966675, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3938308296877009),
#  PowerSensorData(datetime=2023-06-01T12:57:13.489578, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44735388221855227),
#  PowerSensorData(datetime=2023-06-01T12:57:17.769564, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4450119575656661),
#  PowerSensorData(datetime=2023-06-01T12:57:19.023183, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39474178697176776),
#  PowerSensorData(datetime=2023-06-01T12:57:23.283632, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4055140919442488),
#  PowerSensorData(datetime=2023-06-01T12:57:27.293005, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4123243766929254),
#  PowerSensorData(datetime=2023-06-01T12:57:31.554078, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41924454596356536),
#  PowerSensorData(datetime=2023-06-01T12:57:32.305938, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4706640569899406),
#  PowerSensorData(datetime=2023-06-01T12:57:36.316511, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44458596395896105),
#  PowerSensorData(datetime=2023-06-01T12:57:40.327851, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38979641984202934),
#  PowerSensorData(datetime=2023-06-01T12:57:44.598446, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3865202185088375),
#  PowerSensorData(datetime=2023-06-01T12:57:46.854903, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43868598777847106),
#  PowerSensorData(datetime=2023-06-01T12:57:51.123650, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44279632271428776),
#  PowerSensorData(datetime=2023-06-01T12:57:55.386625, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4496318645701157),
#  PowerSensorData(datetime=2023-06-01T12:57:59.397819, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41990529955175654),
#  PowerSensorData(datetime=2023-06-01T12:58:03.659653, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39044740365333985),
#  PowerSensorData(datetime=2023-06-01T12:58:07.929274, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42659803424716064),
#  PowerSensorData(datetime=2023-06-01T12:58:12.188385, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4589597189210943),
#  PowerSensorData(datetime=2023-06-01T12:58:16.199120, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4245614950388585),
#  PowerSensorData(datetime=2023-06-01T12:58:20.462847, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4076054136742757),
#  PowerSensorData(datetime=2023-06-01T12:58:24.724538, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39798471968932875),
#  PowerSensorData(datetime=2023-06-01T12:58:28.987110, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43107871913914925),
#  PowerSensorData(datetime=2023-06-01T12:58:32.999810, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45406329854188116),
#  PowerSensorData(datetime=2023-06-01T12:58:37.261325, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43888950761015905),
#  PowerSensorData(datetime=2023-06-01T12:58:41.524562, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40518336679550626),
#  PowerSensorData(datetime=2023-06-01T12:58:43.783430, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.46481968504972787),
#  PowerSensorData(datetime=2023-06-01T12:58:44.292687, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4085996212286247),
#  PowerSensorData(datetime=2023-06-01T12:58:48.303918, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4067549876938063),
#  PowerSensorData(datetime=2023-06-01T12:58:52.565983, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39532754168510875),
#  PowerSensorData(datetime=2023-06-01T12:58:56.577985, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.47236998337614816),
#  PowerSensorData(datetime=2023-06-01T12:58:59.835415, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4214807785481063),
#  PowerSensorData(datetime=2023-06-01T12:59:04.098083, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4382802907764255),
#  PowerSensorData(datetime=2023-06-01T12:59:07.358781, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.37318125021909926),
#  PowerSensorData(datetime=2023-06-01T12:59:07.610059, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43725429109513114),
#  PowerSensorData(datetime=2023-06-01T12:59:10.627396, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3799034574109358),
#  PowerSensorData(datetime=2023-06-01T12:59:14.901091, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43801942275680633),
#  PowerSensorData(datetime=2023-06-01T12:59:18.912343, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4260389962174031),
#  PowerSensorData(datetime=2023-06-01T12:59:23.174008, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45044932609183785),
#  PowerSensorData(datetime=2023-06-01T12:59:27.435863, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44628025252285436),
#  PowerSensorData(datetime=2023-06-01T12:59:28.188068, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3961424177354017),
#  PowerSensorData(datetime=2023-06-01T12:59:32.450015, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39567910409406515),
#  PowerSensorData(datetime=2023-06-01T12:59:36.714256, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4441086647200213),
#  PowerSensorData(datetime=2023-06-01T12:59:40.975689, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44667852990687407),
#  PowerSensorData(datetime=2023-06-01T12:59:44.985567, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40707942171674233),
#  PowerSensorData(datetime=2023-06-01T12:59:49.248130, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39619328496200323),
#  PowerSensorData(datetime=2023-06-01T12:59:50.502650, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45366103284691356),
#  PowerSensorData(datetime=2023-06-01T12:59:52.759424, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3791279905170524),
#  PowerSensorData(datetime=2023-06-01T12:59:53.511133, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4372393128561531),
#  PowerSensorData(datetime=2023-06-01T12:59:54.776934, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.36287939449703766),
#  PowerSensorData(datetime=2023-06-01T12:59:55.285240, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4222347409964667),
#  PowerSensorData(datetime=2023-06-01T12:59:59.560709, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40353307517431275),
#  PowerSensorData(datetime=2023-06-01T13:00:03.568313, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4143919358813866),
#  PowerSensorData(datetime=2023-06-01T13:00:05.823826, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.474724450692176),
#  PowerSensorData(datetime=2023-06-01T13:00:10.083740, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4316943043875632),
#  PowerSensorData(datetime=2023-06-01T13:00:14.095473, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41138805951755875),
#  PowerSensorData(datetime=2023-06-01T13:00:18.356504, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3659961700308447),
#  PowerSensorData(datetime=2023-06-01T13:00:22.366688, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.416324003731899),
#  PowerSensorData(datetime=2023-06-01T13:00:25.373164, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4761163454535323),
#  PowerSensorData(datetime=2023-06-01T13:00:28.380741, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42276439898837326),
#  PowerSensorData(datetime=2023-06-01T13:00:32.390848, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4161798952251242),
#  PowerSensorData(datetime=2023-06-01T13:00:36.651982, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43815539567907824),
#  PowerSensorData(datetime=2023-06-01T13:00:36.902612, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38522222580797305),
#  PowerSensorData(datetime=2023-06-01T13:00:38.406899, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4371821917512116),
#  PowerSensorData(datetime=2023-06-01T13:00:38.657318, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3742375925297597),
#  PowerSensorData(datetime=2023-06-01T13:00:39.409258, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4522280333294808),
#  PowerSensorData(datetime=2023-06-01T13:00:43.667830, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4027438148211261),
#  PowerSensorData(datetime=2023-06-01T13:00:47.678297, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.396124330903696),
#  PowerSensorData(datetime=2023-06-01T13:00:51.439562, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4831421595393218),
#  PowerSensorData(datetime=2023-06-01T13:00:55.456068, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4260260234905088),
#  PowerSensorData(datetime=2023-06-01T13:00:59.715806, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3872414047065803),
#  PowerSensorData(datetime=2023-06-01T13:01:03.977972, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39015238491987925),
#  PowerSensorData(datetime=2023-06-01T13:01:08.238153, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39498055420555),
#  PowerSensorData(datetime=2023-06-01T13:01:08.990383, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44873973188850874),
#  PowerSensorData(datetime=2023-06-01T13:01:09.742525, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39054042283791607),
#  PowerSensorData(datetime=2023-06-01T13:01:09.993561, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4612276688918039),
#  PowerSensorData(datetime=2023-06-01T13:01:14.262936, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4626438373922774),
#  PowerSensorData(datetime=2023-06-01T13:01:17.770779, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40483055721511285),
#  PowerSensorData(datetime=2023-06-01T13:01:20.778946, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.34144128267926155),
#  PowerSensorData(datetime=2023-06-01T13:01:21.030039, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39944094908608113),
#  PowerSensorData(datetime=2023-06-01T13:01:25.294031, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40093167127736035),
#  PowerSensorData(datetime=2023-06-01T13:01:29.556672, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44016109229939115),
#  PowerSensorData(datetime=2023-06-01T13:01:33.571426, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.443108474063221),
#  PowerSensorData(datetime=2023-06-01T13:01:37.832133, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3955619629610691),
#  PowerSensorData(datetime=2023-06-01T13:01:42.092233, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4071268506101267),
#  PowerSensorData(datetime=2023-06-01T13:01:46.353422, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4553394678010283),
#  PowerSensorData(datetime=2023-06-01T13:01:50.365442, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4926143832412058),
#  PowerSensorData(datetime=2023-06-01T13:01:51.368348, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4347824059337841),
#  PowerSensorData(datetime=2023-06-01T13:01:55.635658, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.37776268535810015),
#  PowerSensorData(datetime=2023-06-01T13:01:59.899381, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4070339229097593),
#  PowerSensorData(datetime=2023-06-01T13:02:03.658053, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4715387404046193),
#  PowerSensorData(datetime=2023-06-01T13:02:07.920721, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4215258505867935),
#  PowerSensorData(datetime=2023-06-01T13:02:12.180770, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40104972552890883),
#  PowerSensorData(datetime=2023-06-01T13:02:16.193394, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4068968641565819),
#  PowerSensorData(datetime=2023-06-01T13:02:20.456330, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4394222606404474),
#  PowerSensorData(datetime=2023-06-01T13:02:20.706950, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38527747661108863),
#  PowerSensorData(datetime=2023-06-01T13:02:20.958099, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4697248458600687),
#  PowerSensorData(datetime=2023-06-01T13:02:21.459302, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4178097290908318),
#  PowerSensorData(datetime=2023-06-01T13:02:25.474878, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4364070529745139),
#  PowerSensorData(datetime=2023-06-01T13:02:28.233138, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4893195408422187),
#  PowerSensorData(datetime=2023-06-01T13:02:28.485644, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4278137474072942),
#  PowerSensorData(datetime=2023-06-01T13:02:30.993103, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4844891966691745),
#  PowerSensorData(datetime=2023-06-01T13:02:31.243485, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4263678628131573),
#  PowerSensorData(datetime=2023-06-01T13:02:35.505479, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39380589806396643),
#  PowerSensorData(datetime=2023-06-01T13:02:39.779594, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3883812192696151),
#  PowerSensorData(datetime=2023-06-01T13:02:42.287350, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45296101792812354),
#  PowerSensorData(datetime=2023-06-01T13:02:46.550355, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4797010558866501),
#  PowerSensorData(datetime=2023-06-01T13:02:49.306993, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42216844957347477),
#  PowerSensorData(datetime=2023-06-01T13:02:51.062523, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3657739894094827),
#  PowerSensorData(datetime=2023-06-01T13:02:54.319959, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4182869502797555),
#  PowerSensorData(datetime=2023-06-01T13:02:58.596588, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4335254138987063),
#  PowerSensorData(datetime=2023-06-01T13:02:59.348699, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.49250712313690104),
#  PowerSensorData(datetime=2023-06-01T13:03:00.351814, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42707245817498024),
#  PowerSensorData(datetime=2023-06-01T13:03:04.612977, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4191149259088707),
#  PowerSensorData(datetime=2023-06-01T13:03:08.873300, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3866229134973126),
#  PowerSensorData(datetime=2023-06-01T13:03:12.883706, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4353227738240525),
#  PowerSensorData(datetime=2023-06-01T13:03:17.147173, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42287979875640247),
#  PowerSensorData(datetime=2023-06-01T13:03:21.407365, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42289265113881475),
#  PowerSensorData(datetime=2023-06-01T13:03:25.692493, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4179605263216041),
#  PowerSensorData(datetime=2023-06-01T13:03:29.707699, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45067122244570174),
#  PowerSensorData(datetime=2023-06-01T13:03:33.967925, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4118726722778774),
#  PowerSensorData(datetime=2023-06-01T13:03:38.230362, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38550964157202683),
#  PowerSensorData(datetime=2023-06-01T13:03:42.491231, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42144236658546436),
#  PowerSensorData(datetime=2023-06-01T13:03:46.507530, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44290450745784693),
#  PowerSensorData(datetime=2023-06-01T13:03:50.770281, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4175094627422221),
#  PowerSensorData(datetime=2023-06-01T13:03:55.031897, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43666900948320125),
#  PowerSensorData(datetime=2023-06-01T13:03:59.043278, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4160320406114585),
#  PowerSensorData(datetime=2023-06-01T13:04:03.301105, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4123223358812569),
#  PowerSensorData(datetime=2023-06-01T13:04:04.805380, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.36135669681148136),
#  PowerSensorData(datetime=2023-06-01T13:04:07.563246, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43635490281030465),
#  PowerSensorData(datetime=2023-06-01T13:04:08.815553, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3830182491776411),
#  PowerSensorData(datetime=2023-06-01T13:04:10.319467, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4332868930210671),
#  PowerSensorData(datetime=2023-06-01T13:04:14.582754, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4236124969503001),
#  PowerSensorData(datetime=2023-06-01T13:04:18.593283, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4137791631720082),
#  PowerSensorData(datetime=2023-06-01T13:04:22.881149, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3964696282730803),
#  PowerSensorData(datetime=2023-06-01T13:04:26.389712, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4479089231542788),
#  PowerSensorData(datetime=2023-06-01T13:04:30.649424, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4277768545854546),
#  PowerSensorData(datetime=2023-06-01T13:04:32.403577, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3765942886180315),
#  PowerSensorData(datetime=2023-06-01T13:04:36.415259, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42831787892436357),
#  PowerSensorData(datetime=2023-06-01T13:04:40.676131, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43530056670877976),
#  PowerSensorData(datetime=2023-06-01T13:04:44.684949, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4190787953499242),
#  PowerSensorData(datetime=2023-06-01T13:04:48.948469, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4034631512784147),
#  PowerSensorData(datetime=2023-06-01T13:04:53.209827, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4111165905208824),
#  PowerSensorData(datetime=2023-06-01T13:04:57.472413, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41303407057929187),
#  PowerSensorData(datetime=2023-06-01T13:05:01.483335, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4202247351202054),
#  PowerSensorData(datetime=2023-06-01T13:05:05.744935, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3961185791632789),
#  PowerSensorData(datetime=2023-06-01T13:05:10.008948, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40803670550711524),
#  PowerSensorData(datetime=2023-06-01T13:05:13.018450, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4797881578964688),
#  PowerSensorData(datetime=2023-06-01T13:05:15.784347, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4164252880494511),
#  PowerSensorData(datetime=2023-06-01T13:05:16.285508, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4822670519866738),
#  PowerSensorData(datetime=2023-06-01T13:05:18.291029, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41078875674666643),
#  PowerSensorData(datetime=2023-06-01T13:05:21.550229, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3372418411678523),
#  PowerSensorData(datetime=2023-06-01T13:05:22.302060, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38741505622889827),
#  PowerSensorData(datetime=2023-06-01T13:05:24.308524, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.33623940622302134),
#  PowerSensorData(datetime=2023-06-01T13:05:24.558907, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40065191569580566),
#  PowerSensorData(datetime=2023-06-01T13:05:28.820344, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40436124446051497),
#  PowerSensorData(datetime=2023-06-01T13:05:33.082968, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41330445491497886),
#  PowerSensorData(datetime=2023-06-01T13:05:37.346234, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41414227840900836),
#  PowerSensorData(datetime=2023-06-01T13:05:41.358002, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4437239242520857),
#  PowerSensorData(datetime=2023-06-01T13:05:44.867257, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3853734822420838),
#  PowerSensorData(datetime=2023-06-01T13:05:45.368050, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4458384613424831),
#  PowerSensorData(datetime=2023-06-01T13:05:49.648739, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40762089519005923),
#  PowerSensorData(datetime=2023-06-01T13:05:53.658946, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40611506738165715),
#  PowerSensorData(datetime=2023-06-01T13:05:57.920754, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41213298816075233),
#  PowerSensorData(datetime=2023-06-01T13:06:02.181509, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4150918168309723),
#  PowerSensorData(datetime=2023-06-01T13:06:06.441153, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38517369843396054),
#  PowerSensorData(datetime=2023-06-01T13:06:10.453389, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4063898859532089),
#  PowerSensorData(datetime=2023-06-01T13:06:11.456815, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45693575079949517),
#  PowerSensorData(datetime=2023-06-01T13:06:15.718814, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44858521095543186),
#  PowerSensorData(datetime=2023-06-01T13:06:17.973883, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38770894935506006),
#  PowerSensorData(datetime=2023-06-01T13:06:22.237133, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4012861547938683),
#  PowerSensorData(datetime=2023-06-01T13:06:26.499192, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4119638339365207),
#  PowerSensorData(datetime=2023-06-01T13:06:30.763250, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41204322934488563),
#  PowerSensorData(datetime=2023-06-01T13:06:34.273591, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.46983589572947626),
#  PowerSensorData(datetime=2023-06-01T13:06:34.775330, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4133727079390952),
#  PowerSensorData(datetime=2023-06-01T13:06:37.782101, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4745671903201772),
#  PowerSensorData(datetime=2023-06-01T13:06:39.285970, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4182612799100926),
#  PowerSensorData(datetime=2023-06-01T13:06:43.547922, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4292324625250583),
#  PowerSensorData(datetime=2023-06-01T13:06:47.830878, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40641338031759316),
#  PowerSensorData(datetime=2023-06-01T13:06:48.081178, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.47201553438505073),
#  PowerSensorData(datetime=2023-06-01T13:06:48.331279, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41565269407621336),
#  PowerSensorData(datetime=2023-06-01T13:06:52.593790, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43184252206788076),
#  PowerSensorData(datetime=2023-06-01T13:06:56.856943, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4242819078665935),
#  PowerSensorData(datetime=2023-06-01T13:07:00.868121, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.36523084689127466),
#  PowerSensorData(datetime=2023-06-01T13:07:05.127308, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40157025741835656),
#  PowerSensorData(datetime=2023-06-01T13:07:09.388435, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4477651610334321),
#  PowerSensorData(datetime=2023-06-01T13:07:13.650227, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42438772994300544),
#  PowerSensorData(datetime=2023-06-01T13:07:15.403783, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.37426411756999844),
#  PowerSensorData(datetime=2023-06-01T13:07:19.678560, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4117627080313456),
#  PowerSensorData(datetime=2023-06-01T13:07:22.437323, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.47482970142277947),
#  PowerSensorData(datetime=2023-06-01T13:07:23.946627, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4219550504298833),
#  PowerSensorData(datetime=2023-06-01T13:07:24.447705, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4813491610829762),
#  PowerSensorData(datetime=2023-06-01T13:07:24.947958, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43130573683779666),
#  PowerSensorData(datetime=2023-06-01T13:07:25.198686, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4897925506673144),
#  PowerSensorData(datetime=2023-06-01T13:07:27.958048, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4204028564596246),
#  PowerSensorData(datetime=2023-06-01T13:07:31.216927, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3554941619610266),
#  PowerSensorData(datetime=2023-06-01T13:07:35.483837, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38001313870059955),
#  PowerSensorData(datetime=2023-06-01T13:07:37.491061, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44470393396735935),
#  PowerSensorData(datetime=2023-06-01T13:07:41.751041, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44215493819179674),
#  PowerSensorData(datetime=2023-06-01T13:07:45.776097, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38522637646745306),
#  PowerSensorData(datetime=2023-06-01T13:07:49.785066, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38389730615648876),
#  PowerSensorData(datetime=2023-06-01T13:07:54.047891, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4205775337114107),
#  PowerSensorData(datetime=2023-06-01T13:07:58.061293, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4803788235924896),
#  PowerSensorData(datetime=2023-06-01T13:08:01.819976, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4284753814841758),
#  PowerSensorData(datetime=2023-06-01T13:08:04.575946, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.37437196312100485),
#  PowerSensorData(datetime=2023-06-01T13:08:08.839109, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.37002971075739055),
#  PowerSensorData(datetime=2023-06-01T13:08:12.349256, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43782463376657776),
#  PowerSensorData(datetime=2023-06-01T13:08:16.644221, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.48004254413425335),
#  PowerSensorData(datetime=2023-06-01T13:08:20.658020, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45710636437914176),
#  PowerSensorData(datetime=2023-06-01T13:08:21.660848, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40249432087433584),
#  PowerSensorData(datetime=2023-06-01T13:08:24.919586, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3443986481998393),
#  PowerSensorData(datetime=2023-06-01T13:08:29.181064, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.33769666219878747),
#  PowerSensorData(datetime=2023-06-01T13:08:29.432050, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38818647804645373),
#  PowerSensorData(datetime=2023-06-01T13:08:32.943194, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44846326744981163),
#  PowerSensorData(datetime=2023-06-01T13:08:37.210922, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4812998829165425),
#  PowerSensorData(datetime=2023-06-01T13:08:41.472238, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4364740564240333),
#  PowerSensorData(datetime=2023-06-01T13:08:43.479852, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38545347488104764),
#  PowerSensorData(datetime=2023-06-01T13:08:47.742162, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3762060088268748),
#  PowerSensorData(datetime=2023-06-01T13:08:52.005553, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.392297815430933),
#  PowerSensorData(datetime=2023-06-01T13:08:54.262491, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4470777159872975),
#  PowerSensorData(datetime=2023-06-01T13:08:58.525561, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4239730052745282),
#  PowerSensorData(datetime=2023-06-01T13:09:02.787436, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40033502415803063),
#  PowerSensorData(datetime=2023-06-01T13:09:07.051312, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4119292508635774),
#  PowerSensorData(datetime=2023-06-01T13:09:11.065119, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4142719583288264),
#  PowerSensorData(datetime=2023-06-01T13:09:15.327210, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3897692429516704),
#  PowerSensorData(datetime=2023-06-01T13:09:19.588240, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43206349164120283),
#  PowerSensorData(datetime=2023-06-01T13:09:23.851481, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4246733026424422),
#  PowerSensorData(datetime=2023-06-01T13:09:27.866799, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4511224674072085),
#  PowerSensorData(datetime=2023-06-01T13:09:29.130577, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.399460879378197),
#  PowerSensorData(datetime=2023-06-01T13:09:29.381822, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4869881694907757),
#  PowerSensorData(datetime=2023-06-01T13:09:30.143537, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4181857318788143),
#  PowerSensorData(datetime=2023-06-01T13:09:33.655036, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3584802119647954),
#  PowerSensorData(datetime=2023-06-01T13:09:37.917800, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38846157356613265),
#  PowerSensorData(datetime=2023-06-01T13:09:40.175882, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4401077316865594),
#  PowerSensorData(datetime=2023-06-01T13:09:43.936337, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.49357574832961915),
#  PowerSensorData(datetime=2023-06-01T13:09:46.443621, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43120123343276334),
#  PowerSensorData(datetime=2023-06-01T13:09:50.462949, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.37898542120950335),
#  PowerSensorData(datetime=2023-06-01T13:09:54.727952, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3495860541409978),
#  PowerSensorData(datetime=2023-06-01T13:09:58.738505, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.37910660656081335),
#  PowerSensorData(datetime=2023-06-01T13:10:01.244113, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4508282077128062),
#  PowerSensorData(datetime=2023-06-01T13:10:05.504757, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.48258022797339983),
#  PowerSensorData(datetime=2023-06-01T13:10:08.766201, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41153270842827055),
#  PowerSensorData(datetime=2023-06-01T13:10:13.028879, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38766899209650774),
#  PowerSensorData(datetime=2023-06-01T13:10:16.036322, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.32948630071601015),
#  PowerSensorData(datetime=2023-06-01T13:10:18.293166, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3795902173371648),
#  PowerSensorData(datetime=2023-06-01T13:10:20.046302, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4342648314664613),
#  PowerSensorData(datetime=2023-06-01T13:10:24.307556, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4994515499377237),
#  PowerSensorData(datetime=2023-06-01T13:10:24.558150, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4319672587804736),
#  PowerSensorData(datetime=2023-06-01T13:10:28.570881, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4836881993535733),
#  PowerSensorData(datetime=2023-06-01T13:10:30.835615, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42655438529310885),
#  PowerSensorData(datetime=2023-06-01T13:10:33.850618, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3713175360396007),
#  PowerSensorData(datetime=2023-06-01T13:10:38.113141, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3650795957739212),
#  PowerSensorData(datetime=2023-06-01T13:10:40.869998, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42203278648294346),
#  PowerSensorData(datetime=2023-06-01T13:10:45.131461, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.45120003491004423),
#  PowerSensorData(datetime=2023-06-01T13:10:49.143235, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43615241221980733),
#  PowerSensorData(datetime=2023-06-01T13:10:52.910632, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.369703361365479),
#  PowerSensorData(datetime=2023-06-01T13:10:56.922853, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3673159235039287),
#  PowerSensorData(datetime=2023-06-01T13:11:01.185499, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39041021901276757),
#  PowerSensorData(datetime=2023-06-01T13:11:04.445525, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4498318145660549),
#  PowerSensorData(datetime=2023-06-01T13:11:08.707963, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42347679414214967),
#  PowerSensorData(datetime=2023-06-01T13:11:12.972303, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39021786871378183),
#  PowerSensorData(datetime=2023-06-01T13:11:17.235164, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40944545524542414),
#  PowerSensorData(datetime=2023-06-01T13:11:21.246431, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44077545813970953),
#  PowerSensorData(datetime=2023-06-01T13:11:22.499172, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38568737653840784),
#  PowerSensorData(datetime=2023-06-01T13:11:23.251014, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.44147368764806977),
#  PowerSensorData(datetime=2023-06-01T13:11:27.262525, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39603555730271267),
#  PowerSensorData(datetime=2023-06-01T13:11:31.524951, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38525191463866776),
#  PowerSensorData(datetime=2023-06-01T13:11:35.785225, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3748227328465185),
#  PowerSensorData(datetime=2023-06-01T13:11:39.043950, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43945455213632534),
#  PowerSensorData(datetime=2023-06-01T13:11:42.553315, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.49236511177588727),
#  PowerSensorData(datetime=2023-06-01T13:11:44.057364, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4062217944149486),
#  PowerSensorData(datetime=2023-06-01T13:11:48.318503, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3709165889806586),
#  PowerSensorData(datetime=2023-06-01T13:11:52.584435, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41644774027266873),
#  PowerSensorData(datetime=2023-06-01T13:11:56.345001, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.47602213780669905),
#  PowerSensorData(datetime=2023-06-01T13:11:59.102036, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.41871683939270266),
#  PowerSensorData(datetime=2023-06-01T13:11:59.353142, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.471134828627277),
#  PowerSensorData(datetime=2023-06-01T13:12:00.356058, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40982094785380113),
#  PowerSensorData(datetime=2023-06-01T13:12:01.609279, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3585875291084803),
#  PowerSensorData(datetime=2023-06-01T13:12:05.621379, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38291464664893804),
#  PowerSensorData(datetime=2023-06-01T13:12:08.379979, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.43765522140257335),
#  PowerSensorData(datetime=2023-06-01T13:12:12.647409, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42799270817060875),
#  PowerSensorData(datetime=2023-06-01T13:12:16.922555, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3983317102913885),
#  PowerSensorData(datetime=2023-06-01T13:12:20.935164, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.36679000926968536),
#  PowerSensorData(datetime=2023-06-01T13:12:25.198570, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4042754086737765),
#  PowerSensorData(datetime=2023-06-01T13:12:29.459846, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4071970361497781),
#  PowerSensorData(datetime=2023-06-01T13:12:33.721285, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4228678137545015),
#  PowerSensorData(datetime=2023-06-01T13:12:34.724333, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.37188638902798743),
#  PowerSensorData(datetime=2023-06-01T13:12:35.225269, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42194432835420775),
#  PowerSensorData(datetime=2023-06-01T13:12:39.236366, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.42499131292253567),
#  PowerSensorData(datetime=2023-06-01T13:12:43.496969, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3822019684871667),
#  PowerSensorData(datetime=2023-06-01T13:12:47.758815, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3616272451122763),
#  PowerSensorData(datetime=2023-06-01T13:12:52.019340, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4156038226578338),
#  PowerSensorData(datetime=2023-06-01T13:12:54.525515, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.46882078553907647),
#  PowerSensorData(datetime=2023-06-01T13:12:57.531494, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4141414269279526),
#  PowerSensorData(datetime=2023-06-01T13:13:01.792589, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.35680309011653816),
#  PowerSensorData(datetime=2023-06-01T13:13:06.055548, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.39090541810659385),
#  PowerSensorData(datetime=2023-06-01T13:13:10.320630, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3873393172147669),
#  PowerSensorData(datetime=2023-06-01T13:13:14.331674, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.38220041327064463),
#  PowerSensorData(datetime=2023-06-01T13:13:18.595905, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4194521523849543),
#  PowerSensorData(datetime=2023-06-01T13:13:22.859720, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.4272545851238108),
#  PowerSensorData(datetime=2023-06-01T13:13:26.119447, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3590547037796965),
#  PowerSensorData(datetime=2023-06-01T13:13:29.127487, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.486160629242694),
#  PowerSensorData(datetime=2023-06-01T13:13:30.381189, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.40487865930111155),
#  PowerSensorData(datetime=2023-06-01T13:13:33.639039, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.34134151654964684),
#  PowerSensorData(datetime=2023-06-01T13:13:37.900606, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.3115567260025172),
#  PowerSensorData(datetime=2023-06-01T13:13:40.909543, sensor_type=<SensorType.EXTRUDER: 'E'>, power=0.0)]

# %%
from typing import List, Tuple


def calculate_availability_time(data: Dict[Sensor, List[SensorData]]) -> Tuple[float, float]:
    """Calculate the time in seconds where all sensors are available. Target sensors are ignored because they're artificially set and stay 'forever'."""
    availability_from = max(
        sensor_data[0].datetime for sensor, sensor_data in data.items() if sensor.has_frequent_updates
    )

    availability_to = min(
        sensor_data[-1].datetime for sensor, sensor_data in data.items() if sensor.has_frequent_updates
    )
    return availability_from.ceil(), availability_to.floor()

# %%
from typing import Generator, Iterator, TypeVar

T = TypeVar('T', bound=SensorData)
class Interpolator:
    def __init__(self, data: List[T], data_type: Type[T], rate: int) -> 'Interpolator':
        self.data = data
        self.rate = rate
        self.period = 1. / rate
        self.data_type = data_type

    def interpolate(self, start_time: Datetime, end_time: Datetime) -> Iterator[T]:
        raise NotImplementedError()

from typing import Callable, Generator, Iterator, Optional, TypeVar

T = TypeVar('T', bound=SensorData)
class LinearInterpolator(Interpolator):
    """Interpolate data by using the last known value"""
    def __init__(self, data: List[T], rate: int, data_type: Type[T], to_floats: Optional[Callable[[T], List[float]]], from_floats: Optional[Callable[[List[float]], T]]) -> 'Interpolator':
        super().__init__(data, rate, data_type)
    
    def interpolate(self, start_time: Datetime, end_time: Datetime) -> Iterator[T]:
        raise NotImplementedError()
        time = start_time
        while self.data[1].datetime < start_time:
            # Remove all data points that are before the start time so that the first data point is the one that is closest to the start time
            self.data.pop(0)
        while True:
            value = self.data.pop(0)
            while value < time:
                value = self.data.pop(0)
            yield value
            time += self.period

from typing import Iterator

class ConstantInterpolator(Interpolator):
    def __init__(self, data: List[T], rate: int, data_type: Type[T]) -> 'Interpolator':
        super().__init__(data, data_type, rate)
 
    def interpolate(self, start_time: Datetime, end_time: Datetime) -> Iterator[T]:
        time = start_time

        value = None

        while True:
            if time >= end_time:
                break

            if len(self.data) == 0:
                assert value is not None
                yield self.data_type(**{**value.__dict__, 'datetime': time})
                time += self.period
                continue

            value = value or self.data[0]
            # if no more data: keep the last data point
            while len(self.data) > 0 and self.data[0].datetime < time:
                # Remove all data points that are before the current time so that the first data point is the one that is closest before the current time
                value = self.data.pop(0)

            yield self.data_type(**{**value.__dict__, 'datetime': time})

            time += self.period

# %%
from printer_anomaly_detection.dataset.domain import InterpolationType

interpolators: Dict[InterpolationType, Interpolator] = {
    InterpolationType.LINEAR: LinearInterpolator,
    InterpolationType.CONSTANT: ConstantInterpolator,
}

# %%
from typing import List
from printer_anomaly_detection.dataset.domain import InterpolationType, Sensor


class DatasetBuilder:
    def __init__(self, dataset_name: str, rate: int = 1) -> 'DatasetBuilder':
        self.dataset_name = dataset_name
        self.sensors: List[Sensor] = []
        self.interpolations: Dict[Sensor, InterpolationType] = {}
        self.rate: int = rate

    def with_sensors(self, sensors: List[Sensor], interpolation: InterpolationType = InterpolationType.CONSTANT) -> 'DatasetBuilder':
        for sensor in sensors:
            self.with_sensor(sensor, interpolation)
        return self

    def with_sensor(self, sensor: Sensor, interpolation: InterpolationType = InterpolationType.CONSTANT) -> 'DatasetBuilder':
        self.sensors.append(sensor)
        self.interpolations[sensor] = interpolation
        return self

    def build(self) -> pd.DataFrame:
        # read data
        data: Dict[Sensor, List[SensorData]] = {
            sensor: read_csv(dataset_path / sensor_filenames[sensor], sensor_datatypes[sensor])
            for sensor in self.sensors
        }
        
        # calculate availability time
        start, end = calculate_availability_time(data)

        # interpolate data
        interpolated_data = {
            sensor: interpolators[self.interpolations[sensor]](data[sensor], rate=self.rate, data_type=type(sensor_data[0])).interpolate(start, end) for sensor, sensor_data in data.items()
        }

        # merge together into one dataframe
        dataframes = []
        
        for sensor, sensor_data in interpolated_data.items():
            df = pd.DataFrame(
                sensor_data,
            ).drop(columns=['sensor_type'])
            # convert map object at column datetime
            df['datetime'] = df['datetime'].map(lambda x: x.timestamp)
            
            # add prefix to all columns except datetime
            df = df.rename(columns={c: f'{sensor.name.lower()}_{c}' for c in df.columns if c not in ['datetime']})
            dataframes.append(df)
        
        assert len(dataframes) > 0

        df = dataframes.pop(0)
        for other_df in dataframes:
            df = df.merge(other_df, on='datetime')

        return df

# %%
df = DatasetBuilder(DATASET, rate = 4) \
    .with_sensors([
        *Sensor
    ]) \
    .build()
# Out:
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/extruder_power.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/extruder_target.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/extruder_temperature.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/extruder_velocity_sensor.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/gas.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/heater_power.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/heater_target.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/heater_temperature.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/accelerometer.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/magnetometer.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/gyroscope.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/mcu.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/position_sensor.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/position_target.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/velocity_sensor.csv.gz
# /Users/yannick.habecker/projects/personal/printer-anomaly-detection/datasets/hinges_12/velocity_target.csv.gz

# %%
df.min()
# Out:
# datetime       2023-06-01T12:46:59.037435
# sensor_type                             M
# velocity                            300.0
# dtype: object

# %%
df = pd.read_csv(dataset_path / sensor_filenames[Sensor.GAS])
df.min()
# Out:
# datetime       2023-06-01T12:42:49.057539+00:00
# sensor_type                                   C
# value                                      83.0
# dtype: object

# %%
df = DatasetBuilder(DATASET, rate = 1) \
    .with_sensor(Sensor.VELOCITY) \
    .build()
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 3
#       1 df = DatasetBuilder(DATASET, rate = 5) \
#       2     .with_sensor(Sensor.VELOCITY) \
# ----> 3     .build()
#
# Cell In[48], line 25, in DatasetBuilder.build(self)
#      19 data: Dict[Sensor, List[SensorData]] = {
#      20     sensor: read_csv(dataset_path / sensor_filenames[sensor], sensor_datatypes[sensor])
#      21     for sensor in self.sensors
#      22 }
#      24 # calculate availability time
# ---> 25 start, end = calculate_availability_time(data)
#      27 # interpolate data
#      28 interpolated_data = {
#      29     sensor: interpolators[self.interpolations[sensor]](data[sensor], rate=self.rate, data_type=type(sensor_data[0])).interpolate(start, end) for sensor, sensor_data in data.items()
#      30 }
#
# Cell In[45], line 6, in calculate_availability_time(data)
#       4 def calculate_availability_time(data: Dict[Sensor, List[SensorData]]) -> Tuple[float, float]:
#       5     """Calculate the time in seconds where all sensors are available. Target sensors are ignored because they're artificially set and stay 'forever'."""
# ----> 6     availability_from = max(
#       7         sensor_data[0].datetime for sensor, sensor_data in data.items() if sensor.has_frequent_updates
#       8     )
#      10     availability_to = min(
#      11         sensor_data[-1].datetime for sensor, sensor_data in data.items() if sensor.has_frequent_updates
#      12     )
#      13     return availability_from.ceil(), availability_to.floor()
#
# ValueError: max() arg is an empty sequence

# %%
data: Dict[Sensor, List[SensorData]] = {
    sensor: read_csv(dataset_path / sensor_filenames[sensor], sensor_datatypes[sensor])
    for sensor in builder.sensors
}

availability_from, availability_to = calculate_availability_time(data)
print(availability_from, availability_to)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 data: Dict[Sensor, List[SensorData]] = {
#       2     sensor: read_csv(dataset_path / sensor_filenames[sensor], sensor_datatypes[sensor])
# ----> 3     for sensor in builder.sensors
#       4 }
#       6 availability_from, availability_to = calculate_availability_time(data)
#       7 print(availability_from, availability_to)
#
# NameError: name 'builder' is not defined

# %%
interpolation_data = list(data[Sensor.EXTRUDER_TARGET])
print(len(interpolation_data))
interpolated = ConstantInterpolator(interpolation_data, 0.005, TargetData)\
    .interpolate(availability_from, availability_to)

for d in list(interpolated):
    print(d)

# %%
# todo: read all data
# find time when all are available
# up/downsample
